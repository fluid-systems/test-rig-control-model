# %%
import matplotlib.pyplot as plt
from testrig_control_with_sofirpy.experimental_run import ExperimentalRun
from sofirpy import plot_results
import test_rig_control_model.common as co
from testrig_control_with_sofirpy.utils import get_run_names_from_file

# %%
file_name = "system_1_constant_operating_point_3536_50.hdf5"  # "subsystem_1_step_response_operating_point_2kPa.hdf5"
run_names = get_run_names_from_file(co.DATA_DIR / file_name)
usable_runs = run_names
run = ExperimentalRun.from_hdf5(usable_runs[2], co.DATA_DIR / file_name)
# Out:
# HDF5ToRun::WARNING::The following dependencies were installed when storing the run in the hdf5 and are not installed in the current environment:
# mypy-extensions, future
# HDF5ToRun::WARNING::The following dependencies have a different version: h5py, pillow, pytest-cov, scikit-learn, matplotlib, filelock, lxml, pytz, pandas-stubs, pyzmq, certifi, statsmodels, packaging, FMPy, uncertainties, tzlocal, pytest, charset-normalizer, pre_commit, coverage, pip, MarkupSafe, tables, scipy, mypy, urllib3, distlib, OMPython, identify, fonttools, joblib, Jinja2, pywin32, attrs, six, kiwisolver, pluggy, requests, PyYAML, platformdirs, idna, python-gitlab, msgpack, types-pytz, psutil, pandas, tzdata, click, contourpy, numpy, blosc2, cloudpickle, numexpr, virtualenv, ruff, types-tqdm, lark, typing_extensions, ruptures, iniconfig, nidaqmx, hightime, ndindex, patsy, pyparsing
# ...

# %%
plot_results(run.time_series, "time", ["test_rig.pump_1_pressure"])
plt.show()

# %%
plot_results(run.time_series, "time", ["test_rig.tank_1_pressure"])
plt.show()

# %%
plot_results(run.time_series, "time", ["test_rig.consumer_1_volume_flow"])
plt.show()

# %%
plot_results(run.time_series, "time", ["test_rig.consumer_1_valve_opening"])
plt.show()

# %%
plot_results(run.time_series, "time", ["pump_1.output"])
plt.show()

# %%
run.init_configs["pump_1"]
# Out:
# {'min_output': 23.333333,
#  'max_output': 74.166667,
#  'units': {'output': 'https://qudt.org/vocab/unit/REV-PER-SEC'},
#  'starting_output': 35.36}

# %%
run.init_configs["consumer_valve_1"]
# Out:
# {'start_time': 90,
#  'duration': 900,
#  'onset_time': 5,
#  'time_between_disruptions': 140,
#  'sample_period': 0.05,
#  'step_number': 1,
#  'step_size': 50,
#  'shape': 'step',
#  'min_output': 0.0,
#  'max_output': 100.0,
#  'units': {'output': 'https://qudt.org/vocab/unit/PERCENT'},
#  'starting_output': 0.0}
